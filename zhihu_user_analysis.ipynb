# %%
import pandas as pd
data = pd.read_csv('zhihu_user.csv',encoding='gbk')
data
# Out:
#        Unnamed: 0  answer_count  follower_count  gender           name
# 0               0         20299          752645       1           vczh
# 1               1            65            5182       1         崔庆才丨静觅
# 2               2           279           87413      -1        阿里云云栖社区
# 3               3           254           37549       1        Crossin
# 4               4             9             526       0           我是米酒
# 5               5            35            9127      -1      壹球ONEBALL
# 6               6           206             181      -1      要是有如果该多好啊
# 7               7            93           13307       1             少年
# 8               8            17           45165      -1            量子位
# 9               9           795          736160      -1   KnowYourself
# 10             10             1             159       1            TED
# 11             11            52           58962       1          原画册韩松
# ...

# %% [markdown]
# # 去重+降序排序

# %%
result = data.drop_duplicates('name').sort_values(by='follower_count',ascending=False)
result
# Out:
#        Unnamed: 0  answer_count  follower_count  gender          name
# 19             19          3351         1776071       1           张佳玮
# 147           147           384         1349721      -1          丁香医生
# 1295         1295           109         1058107      -1           李开复
# 653           653           338          913186       1            周源
# 1004         1004           782          850073       1           黄继新
# 268           268          1465          841025       1            张亮
# 4177         4177          1619          796411       1       yolfilm
# 0               0         20299          752645       1          vczh
# 9               9           795          736160      -1  KnowYourself
# 441           441           223          730968       1            朱炫
# 4503         4503          1166          725358       1            李淼
# 185           185           160          719710       0           寺主人
# ...

# %%
result[result['follower_count']>1000]
# Out:
#        Unnamed: 0  answer_count  follower_count  gender          name
# 19             19          3351         1776071       1           张佳玮
# 147           147           384         1349721      -1          丁香医生
# 1295         1295           109         1058107      -1           李开复
# 653           653           338          913186       1            周源
# 1004         1004           782          850073       1           黄继新
# 268           268          1465          841025       1            张亮
# 4177         4177          1619          796411       1       yolfilm
# 0               0         20299          752645       1          vczh
# 9               9           795          736160      -1  KnowYourself
# 441           441           223          730968       1            朱炫
# 4503         4503          1166          725358       1            李淼
# 185           185           160          719710       0           寺主人
# ...
